# %% [markdown]
# # 📖 Introduction

# %% [markdown]
# The goal of this project is to develop a deep learning model that can accurately classify facial expressions into one of seven categories: Angry, Disgust, Fear, Happy, Sad, Surprise, and Neutral. We will use convolutional neural networks (CNNs) to train our model, as they have been shown to be effective in image classification tasks. Our approach involves training a CNN model from scratch on the FER-2013 dataset
#
# ![emotions.png](attachment:02a21be9-12eb-4595-a450-8414036bac30.png)

# %% [markdown]
# # 💾 Data

# %% [markdown]
# The FER-2013 dataset consists of 48x48 pixel grayscale images of faces that have been automatically registered to be centred and occupy a similar amount of space in each image. The dataset contains 24,400 images, with 22,968 examples in the training set and 1,432 examples in the public test set.

# %% [markdown]
# # 🛠 Preprocessing

# %% [markdown]
# In this section, we will be using both data generators and data augmentation to train a deep learning model for human emotion detection using the FER-2013 dataset. Due to the size and complexity of the dataset, it would be impractical to load all of the images into memory at once. Therefore, we will be using data generators to generate batches of images on-the-fly during training, which will allow us to efficiently train our model on the entire dataset.
#
# In addition, we will be applying various data augmentation techniques to the training images, such as rotation, shifting, and flipping. This will help to increase the size and diversity of our training set, which can improve the performance of our deep learning model. By introducing variability into the training process, data augmentation can also help to prevent overfitting, which occurs when the model becomes too closely tailored to the training set and performs poorly on new, unseen data.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "../input/fer2013/train" # Directory containing the training data
test_dir = "../input/fer2013/test"  # Directory containing the validation data

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %% [markdown]
# # Modeling

# %% [markdown]
# ## CNN Model

# %% [markdown]
# To develop the CNN architecture, we will begin by defining the input layer and the number of filters in the first convolutional layer. Then, we will add additional convolutional layers with increasing numbers of filters, followed by max-pooling layers to reduce the spatial dimensions of the feature maps. After the convolutional layers, we will add fully connected layers with ReLU activation to classify the emotions.
#
# We will experiment with different numbers of convolutional layers, filter sizes, and fully connected layers to optimize the model performance. Additionally, we will use techniques such as dropout and batch normalization to prevent overfitting and improve the generalization capability of the model.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(lr=0.0001), metrics=['accuracy'])

# %%
# Save the entire model (architecture + weights)
from tensorflow.keras.preprocessing import image
import numpy as np
model.save('my_model.h5')

# Load the model for inference
model = tf.keras.models.load_model('my_model.h5')

# Function to preprocess the image and make predictions
def classify_image(img_path):
    # Load the image
    img = image.load_img(img_path, target_size=(48, 48), color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  
    img_array = img_array / 255.0 

    # Make a prediction
    predictions = model.predict(img_array)
    
    # Get the predicted class index
    predicted_class = np.argmax(predictions, axis=1)
    
    return predicted_class

# Example usage
img_path = '/kaggle/input/fer2013/test/happy/PrivateTest_11281040.jpg'  # Replace with the path to your image
predicted_class = classify_image(img_path)
print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 5s 5s/step
# Predicted class: [3]

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=70,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/70
# 2024-11-01 12:21:02.490412: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 359/359 [==============================] - ETA: 0s - loss: 2.1853 - accuracy: 0.2469
# Epoch 1: val_accuracy improved from -inf to 0.27235, saving model to model_weights.h5
# 359/359 [==============================] - 118s 311ms/step - loss: 2.1853 - accuracy: 0.2469 - val_loss: 1.7802 - val_accuracy: 0.2723
# Epoch 2/70
# 359/359 [==============================] - ETA: 0s - loss: 1.6767 - accuracy: 0.3646
# Epoch 2: val_accuracy improved from 0.27235 to 0.38966, saving model to model_weights.h5
# 359/359 [==============================] - 34s 95ms/step - loss: 1.6767 - accuracy: 0.3646 - val_loss: 1.5793 - val_accuracy: 0.3897
# Epoch 3/70
# 359/359 [==============================] - ETA: 0s - loss: 1.4722 - accuracy: 0.4380
# Epoch 3: val_accuracy improved from 0.38966 to 0.49511, saving model to model_weights.h5
# 359/359 [==============================] - 31s 87ms/step - loss: 1.4722 - accuracy: 0.4380 - val_loss: 1.3504 - val_accuracy: 0.4951
# Epoch 4/70
# 359/359 [==============================] - ETA: 0s - loss: 1.3638 - accuracy: 0.4781
# Epoch 4: val_accuracy did not improve from 0.49511
# 359/359 [==============================] - 33s 91ms/step - loss: 1.3638 - accuracy: 0.4781 - val_loss: 1.4956 - val_accuracy: 0.4672
# Epoch 5/70
# 359/359 [==============================] - ETA: 0s - loss: 1.2834 - accuracy: 0.5117
# Epoch 5: val_accuracy improved from 0.49511 to 0.50349, saving model to model_weights.h5
# 359/359 [==============================] - 33s 92ms/step - loss: 1.2834 - accuracy: 0.5117 - val_loss: 1.3409 - val_accuracy: 0.5035
# Epoch 6/70
# 359/359 [==============================] - ETA: 0s - loss: 1.2479 - accuracy: 0.5260
# Epoch 6: val_accuracy improved from 0.50349 to 0.51466, saving model to model_weights.h5
# 359/359 [==============================] - 36s 99ms/step - loss: 1.2479 - accuracy: 0.5260 - val_loss: 1.3550 - val_accuracy: 0.5147
# Epoch 7/70
# 359/359 [==============================] - ETA: 0s - loss: 1.2023 - accuracy: 0.5445
# Epoch 7: val_accuracy improved from 0.51466 to 0.58101, saving model to model_weights.h5
# 359/359 [==============================] - 32s 90ms/step - loss: 1.2023 - accuracy: 0.5445 - val_loss: 1.1173 - val_accuracy: 0.5810
# Epoch 8/70
# 359/359 [==============================] - ETA: 0s - loss: 1.1858 - accuracy: 0.5529
# Epoch 8: val_accuracy did not improve from 0.58101
# 359/359 [==============================] - 32s 89ms/step - loss: 1.1858 - accuracy: 0.5529 - val_loss: 1.1202 - val_accuracy: 0.5789
# Epoch 9/70
# 359/359 [==============================] - ETA: 0s - loss: 1.1481 - accuracy: 0.5658
# Epoch 9: val_accuracy improved from 0.58101 to 0.59567, saving model to model_weights.h5
# 359/359 [==============================] - 32s 89ms/step - loss: 1.1481 - accuracy: 0.5658 - val_loss: 1.0618 - val_accuracy: 0.5957
# Epoch 10/70
# 359/359 [==============================] - ETA: 0s - loss: 1.1373 - accuracy: 0.5692
# Epoch 10: val_accuracy did not improve from 0.59567
# 359/359 [==============================] - 31s 85ms/step - loss: 1.1373 - accuracy: 0.5692 - val_loss: 1.0840 - val_accuracy: 0.5908
# Epoch 11/70
# 359/359 [==============================] - ETA: 0s - loss: 1.1141 - accuracy: 0.5844
# Epoch 11: val_accuracy improved from 0.59567 to 0.60056, saving model to model_weights.h5
# 359/359 [==============================] - 32s 90ms/step - loss: 1.1141 - accuracy: 0.5844 - val_loss: 1.0568 - val_accuracy: 0.6006
# Epoch 12/70
# 359/359 [==============================] - ETA: 0s - loss: 1.0928 - accuracy: 0.5906
# Epoch 12: val_accuracy improved from 0.60056 to 0.60684, saving model to model_weights.h5
# 359/359 [==============================] - 31s 87ms/step - loss: 1.0928 - accuracy: 0.5906 - val_loss: 1.0894 - val_accuracy: 0.6068
# Epoch 13/70
# 359/359 [==============================] - ETA: 0s - loss: 1.0798 - accuracy: 0.5950
# Epoch 13: val_accuracy improved from 0.60684 to 0.62989, saving model to model_weights.h5
# 359/359 [==============================] - 32s 90ms/step - loss: 1.0798 - accuracy: 0.5950 - val_loss: 0.9904 - val_accuracy: 0.6299
# Epoch 14/70
# 359/359 [==============================] - ETA: 0s - loss: 1.0640 - accuracy: 0.6020
# Epoch 14: val_accuracy did not improve from 0.62989
# 359/359 [==============================] - 31s 86ms/step - loss: 1.0640 - accuracy: 0.6020 - val_loss: 1.0419 - val_accuracy: 0.6027
# Epoch 15/70
# 359/359 [==============================] - ETA: 0s - loss: 1.0483 - accuracy: 0.6060
# Epoch 15: val_accuracy did not improve from 0.62989
# 359/359 [==============================] - 32s 88ms/step - loss: 1.0483 - accuracy: 0.6060 - val_loss: 1.0246 - val_accuracy: 0.6166
# Epoch 16/70
# 359/359 [==============================] - ETA: 0s - loss: 1.0393 - accuracy: 0.6112
# Epoch 16: val_accuracy did not improve from 0.62989
# 359/359 [==============================] - 30s 84ms/step - loss: 1.0393 - accuracy: 0.6112 - val_loss: 1.0338 - val_accuracy: 0.6124
# Epoch 17/70
# 359/359 [==============================] - ETA: 0s - loss: 1.0246 - accuracy: 0.6180
# Epoch 17: val_accuracy did not improve from 0.62989
# 359/359 [==============================] - 31s 87ms/step - loss: 1.0246 - accuracy: 0.6180 - val_loss: 1.0105 - val_accuracy: 0.6285
# Epoch 18/70
# 359/359 [==============================] - ETA: 0s - loss: 1.0089 - accuracy: 0.6220
# Epoch 18: val_accuracy did not improve from 0.62989
# 359/359 [==============================] - 30s 83ms/step - loss: 1.0089 - accuracy: 0.6220 - val_loss: 1.0141 - val_accuracy: 0.6299
# Epoch 19/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9952 - accuracy: 0.6307
# Epoch 19: val_accuracy improved from 0.62989 to 0.63128, saving model to model_weights.h5
# 359/359 [==============================] - 31s 87ms/step - loss: 0.9952 - accuracy: 0.6307 - val_loss: 0.9934 - val_accuracy: 0.6313
# Epoch 20/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9778 - accuracy: 0.6327
# Epoch 20: val_accuracy improved from 0.63128 to 0.64036, saving model to model_weights.h5
# 359/359 [==============================] - 30s 84ms/step - loss: 0.9778 - accuracy: 0.6327 - val_loss: 0.9877 - val_accuracy: 0.6404
# Epoch 21/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9718 - accuracy: 0.6375
# Epoch 21: val_accuracy did not improve from 0.64036
# 359/359 [==============================] - 32s 89ms/step - loss: 0.9718 - accuracy: 0.6375 - val_loss: 1.0039 - val_accuracy: 0.6215
# Epoch 22/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9588 - accuracy: 0.6423
# Epoch 22: val_accuracy did not improve from 0.64036
# 359/359 [==============================] - 32s 89ms/step - loss: 0.9588 - accuracy: 0.6423 - val_loss: 1.0095 - val_accuracy: 0.6124
# Epoch 23/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9435 - accuracy: 0.6476
# Epoch 23: val_accuracy did not improve from 0.64036
# 359/359 [==============================] - 32s 88ms/step - loss: 0.9435 - accuracy: 0.6476 - val_loss: 1.0106 - val_accuracy: 0.6229
# Epoch 24/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9394 - accuracy: 0.6491
# Epoch 24: val_accuracy did not improve from 0.64036
# 359/359 [==============================] - 32s 89ms/step - loss: 0.9394 - accuracy: 0.6491 - val_loss: 0.9696 - val_accuracy: 0.6327
# Epoch 25/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9303 - accuracy: 0.6526
# Epoch 25: val_accuracy did not improve from 0.64036
# 359/359 [==============================] - 32s 88ms/step - loss: 0.9303 - accuracy: 0.6526 - val_loss: 0.9532 - val_accuracy: 0.6355
# Epoch 26/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9158 - accuracy: 0.6579
# Epoch 26: val_accuracy improved from 0.64036 to 0.64176, saving model to model_weights.h5
# 359/359 [==============================] - 32s 89ms/step - loss: 0.9158 - accuracy: 0.6579 - val_loss: 0.9950 - val_accuracy: 0.6418
# Epoch 27/70
# 359/359 [==============================] - ETA: 0s - loss: 0.9041 - accuracy: 0.6661
# Epoch 27: val_accuracy did not improve from 0.64176
# 359/359 [==============================] - 31s 86ms/step - loss: 0.9041 - accuracy: 0.6661 - val_loss: 1.0022 - val_accuracy: 0.6250
# Epoch 28/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8967 - accuracy: 0.6660
# Epoch 28: val_accuracy improved from 0.64176 to 0.64525, saving model to model_weights.h5
# 359/359 [==============================] - 33s 92ms/step - loss: 0.8967 - accuracy: 0.6660 - val_loss: 0.9716 - val_accuracy: 0.6453
# Epoch 29/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8799 - accuracy: 0.6688
# Epoch 29: val_accuracy improved from 0.64525 to 0.64944, saving model to model_weights.h5
# 359/359 [==============================] - 34s 94ms/step - loss: 0.8799 - accuracy: 0.6688 - val_loss: 0.9618 - val_accuracy: 0.6494
# Epoch 30/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8785 - accuracy: 0.6709
# Epoch 30: val_accuracy did not improve from 0.64944
# 359/359 [==============================] - 34s 95ms/step - loss: 0.8785 - accuracy: 0.6709 - val_loss: 0.9691 - val_accuracy: 0.6362
# Epoch 31/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8685 - accuracy: 0.6777
# Epoch 31: val_accuracy did not improve from 0.64944
# 359/359 [==============================] - 33s 92ms/step - loss: 0.8685 - accuracy: 0.6777 - val_loss: 0.9504 - val_accuracy: 0.6446
# Epoch 32/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8555 - accuracy: 0.6841
# Epoch 32: val_accuracy did not improve from 0.64944
# 359/359 [==============================] - 34s 95ms/step - loss: 0.8555 - accuracy: 0.6841 - val_loss: 0.9909 - val_accuracy: 0.6432
# Epoch 33/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8511 - accuracy: 0.6819
# Epoch 33: val_accuracy did not improve from 0.64944
# 359/359 [==============================] - 32s 89ms/step - loss: 0.8511 - accuracy: 0.6819 - val_loss: 0.9695 - val_accuracy: 0.6487
# Epoch 34/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8427 - accuracy: 0.6867
# Epoch 34: val_accuracy did not improve from 0.64944
# 359/359 [==============================] - 34s 94ms/step - loss: 0.8427 - accuracy: 0.6867 - val_loss: 0.9849 - val_accuracy: 0.6299
# Epoch 35/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8358 - accuracy: 0.6908
# Epoch 35: val_accuracy improved from 0.64944 to 0.65852, saving model to model_weights.h5
# 359/359 [==============================] - 32s 88ms/step - loss: 0.8358 - accuracy: 0.6908 - val_loss: 0.9118 - val_accuracy: 0.6585
# Epoch 36/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8313 - accuracy: 0.6878
# Epoch 36: val_accuracy improved from 0.65852 to 0.65922, saving model to model_weights.h5
# 359/359 [==============================] - 32s 90ms/step - loss: 0.8313 - accuracy: 0.6878 - val_loss: 0.9284 - val_accuracy: 0.6592
# Epoch 37/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8183 - accuracy: 0.6961
# Epoch 37: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 31s 86ms/step - loss: 0.8183 - accuracy: 0.6961 - val_loss: 1.0660 - val_accuracy: 0.6334
# Epoch 38/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8118 - accuracy: 0.6989
# Epoch 38: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 31s 87ms/step - loss: 0.8118 - accuracy: 0.6989 - val_loss: 0.9882 - val_accuracy: 0.6480
# Epoch 39/70
# 359/359 [==============================] - ETA: 0s - loss: 0.8001 - accuracy: 0.7022
# Epoch 39: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 31s 87ms/step - loss: 0.8001 - accuracy: 0.7022 - val_loss: 0.9589 - val_accuracy: 0.6536
# Epoch 40/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7982 - accuracy: 0.7050
# Epoch 40: val_accuracy improved from 0.65922 to 0.66271, saving model to model_weights.h5
# 359/359 [==============================] - 32s 89ms/step - loss: 0.7982 - accuracy: 0.7050 - val_loss: 0.9947 - val_accuracy: 0.6627
# Epoch 41/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7876 - accuracy: 0.7094
# Epoch 41: val_accuracy improved from 0.66271 to 0.66899, saving model to model_weights.h5
# 359/359 [==============================] - 31s 86ms/step - loss: 0.7876 - accuracy: 0.7094 - val_loss: 0.9570 - val_accuracy: 0.6690
# Epoch 42/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7806 - accuracy: 0.7129
# Epoch 42: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 31s 85ms/step - loss: 0.7806 - accuracy: 0.7129 - val_loss: 0.9908 - val_accuracy: 0.6529
# Epoch 43/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7709 - accuracy: 0.7125
# Epoch 43: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 33s 90ms/step - loss: 0.7709 - accuracy: 0.7125 - val_loss: 0.9515 - val_accuracy: 0.6557
# Epoch 44/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7695 - accuracy: 0.7119
# Epoch 44: val_accuracy improved from 0.66899 to 0.67528, saving model to model_weights.h5
# 359/359 [==============================] - 31s 86ms/step - loss: 0.7695 - accuracy: 0.7119 - val_loss: 0.9356 - val_accuracy: 0.6753
# Epoch 45/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7545 - accuracy: 0.7161
# Epoch 45: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 32s 89ms/step - loss: 0.7545 - accuracy: 0.7161 - val_loss: 1.0135 - val_accuracy: 0.6487
# Epoch 46/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7527 - accuracy: 0.7194
# Epoch 46: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 31s 85ms/step - loss: 0.7527 - accuracy: 0.7194 - val_loss: 0.9911 - val_accuracy: 0.6557
# Epoch 47/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7509 - accuracy: 0.7225
# Epoch 47: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 32s 88ms/step - loss: 0.7509 - accuracy: 0.7225 - val_loss: 0.9875 - val_accuracy: 0.6487
# Epoch 48/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7364 - accuracy: 0.7261
# Epoch 48: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 31s 86ms/step - loss: 0.7364 - accuracy: 0.7261 - val_loss: 1.2108 - val_accuracy: 0.6034
# Epoch 49/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7332 - accuracy: 0.7291
# Epoch 49: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 32s 89ms/step - loss: 0.7332 - accuracy: 0.7291 - val_loss: 0.9868 - val_accuracy: 0.6599
# Epoch 50/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7340 - accuracy: 0.7271
# Epoch 50: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 31s 85ms/step - loss: 0.7340 - accuracy: 0.7271 - val_loss: 0.9377 - val_accuracy: 0.6711
# Epoch 51/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.7311
# Epoch 51: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 32s 89ms/step - loss: 0.7191 - accuracy: 0.7311 - val_loss: 0.9352 - val_accuracy: 0.6662
# Epoch 52/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7134 - accuracy: 0.7378
# Epoch 52: val_accuracy did not improve from 0.67528
# 359/359 [==============================] - 30s 83ms/step - loss: 0.7134 - accuracy: 0.7378 - val_loss: 1.0043 - val_accuracy: 0.6501
# Epoch 53/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7013 - accuracy: 0.7399
# Epoch 53: val_accuracy improved from 0.67528 to 0.68087, saving model to model_weights.h5
# 359/359 [==============================] - 33s 91ms/step - loss: 0.7013 - accuracy: 0.7399 - val_loss: 0.9900 - val_accuracy: 0.6809
# Epoch 54/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.7449
# Epoch 54: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 30s 85ms/step - loss: 0.6945 - accuracy: 0.7449 - val_loss: 1.0333 - val_accuracy: 0.6439
# Epoch 55/70
# 359/359 [==============================] - ETA: 0s - loss: 0.7042 - accuracy: 0.7393
# Epoch 55: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 32s 89ms/step - loss: 0.7042 - accuracy: 0.7393 - val_loss: 0.9907 - val_accuracy: 0.6564
# Epoch 56/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6791 - accuracy: 0.7460
# Epoch 56: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 30s 84ms/step - loss: 0.6791 - accuracy: 0.7460 - val_loss: 0.9666 - val_accuracy: 0.6599
# Epoch 57/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.7463
# Epoch 57: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 31s 87ms/step - loss: 0.6852 - accuracy: 0.7463 - val_loss: 0.9745 - val_accuracy: 0.6711
# Epoch 58/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6757 - accuracy: 0.7497
# Epoch 58: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 30s 84ms/step - loss: 0.6757 - accuracy: 0.7497 - val_loss: 0.9571 - val_accuracy: 0.6725
# Epoch 59/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6745 - accuracy: 0.7500
# Epoch 59: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 31s 86ms/step - loss: 0.6745 - accuracy: 0.7500 - val_loss: 0.9626 - val_accuracy: 0.6774
# Epoch 60/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6722 - accuracy: 0.7508
# Epoch 60: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 31s 85ms/step - loss: 0.6722 - accuracy: 0.7508 - val_loss: 0.9813 - val_accuracy: 0.6606
# Epoch 61/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6684 - accuracy: 0.7515
# Epoch 61: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 32s 88ms/step - loss: 0.6684 - accuracy: 0.7515 - val_loss: 1.0107 - val_accuracy: 0.6578
# Epoch 62/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6548 - accuracy: 0.7566
# Epoch 62: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 31s 86ms/step - loss: 0.6548 - accuracy: 0.7566 - val_loss: 0.9714 - val_accuracy: 0.6732
# Epoch 63/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6469 - accuracy: 0.7593
# Epoch 63: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 31s 86ms/step - loss: 0.6469 - accuracy: 0.7593 - val_loss: 0.9593 - val_accuracy: 0.6767
# Epoch 64/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6424 - accuracy: 0.7635
# Epoch 64: val_accuracy did not improve from 0.68087
# 359/359 [==============================] - 31s 87ms/step - loss: 0.6424 - accuracy: 0.7635 - val_loss: 0.9583 - val_accuracy: 0.6711
# Epoch 65/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6467 - accuracy: 0.7602
# Epoch 65: val_accuracy improved from 0.68087 to 0.68436, saving model to model_weights.h5
# 359/359 [==============================] - 31s 86ms/step - loss: 0.6467 - accuracy: 0.7602 - val_loss: 0.9346 - val_accuracy: 0.6844
# Epoch 66/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6445 - accuracy: 0.7640
# Epoch 66: val_accuracy did not improve from 0.68436
# 359/359 [==============================] - 34s 94ms/step - loss: 0.6445 - accuracy: 0.7640 - val_loss: 0.9609 - val_accuracy: 0.6760
# Epoch 67/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.7696
# Epoch 67: val_accuracy did not improve from 0.68436
# 359/359 [==============================] - 31s 85ms/step - loss: 0.6265 - accuracy: 0.7696 - val_loss: 0.9542 - val_accuracy: 0.6774
# Epoch 68/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6281 - accuracy: 0.7662
# Epoch 68: val_accuracy improved from 0.68436 to 0.68506, saving model to model_weights.h5
# 359/359 [==============================] - 32s 88ms/step - loss: 0.6281 - accuracy: 0.7662 - val_loss: 0.9588 - val_accuracy: 0.6851
# Epoch 69/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.7723
# Epoch 69: val_accuracy did not improve from 0.68506
# 359/359 [==============================] - 31s 85ms/step - loss: 0.6203 - accuracy: 0.7723 - val_loss: 0.9852 - val_accuracy: 0.6669
# Epoch 70/70
# 359/359 [==============================] - ETA: 0s - loss: 0.6165 - accuracy: 0.7712
# Epoch 70: val_accuracy did not improve from 0.68506
# 359/359 [==============================] - 32s 89ms/step - loss: 0.6165 - accuracy: 0.7712 - val_loss: 0.9604 - val_accuracy: 0.6718

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training and validation loss curves

# %%
import matplotlib.pyplot as plt
# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Save the entire model (architecture + weights)
from tensorflow.keras.preprocessing import image
import numpy as np
model.save('my_model.h5')

# Load the model for inference
model = tf.keras.models.load_model('my_model.h5')

# Function to preprocess the image and make predictions
def classify_image(img_path):
    # Load the image
    img = image.load_img(img_path, target_size=(48, 48), color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  
    img_array = img_array / 255.0 

    # Make a prediction
    predictions = model.predict(img_array)
    
    # Get the predicted class index
    predicted_class = np.argmax(predictions, axis=1)
    
    return predicted_class

# Example usage
img_path = '/kaggle/input/fer2013/test/happy/PrivateTest_11281040.jpg'  # Replace with the path to your image
predicted_class = classify_image(img_path)
print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 186ms/step
# Predicted class: [3]

# %% [markdown]
# ### Training and validation accuracy curves

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 [==============================] - 1s 52ms/step
